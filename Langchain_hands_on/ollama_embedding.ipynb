# %% [markdown]
# ### Ollama
#
# Ollama Supports embedding models , making it possible to build retrieval augmented generation (RAG) applications that combine text prompts with existing documents or other data.

# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
# Create Embdding
embedding =OllamaEmbeddings(model="nomic-embed-text:v1.5")                   # by default it used ollam 2 model

# %%
embedding
# Out:
# OllamaEmbeddings(base_url='http://localhost:11434', model='nomic-embed-text:v1.5', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
r1 = embedding.embed_documents(
    [
        "Alpha is the First character of Greek Alphabet",
        "Beta is the Second character of Greek Alphabet",
    ]
)

# %%
r1
# Out:
# [[-0.24675239622592926,
#   0.5098170042037964,
#   -3.540954828262329,
#   -2.1430249214172363,
#   1.3275978565216064,
#   -0.22501417994499207,
#   -0.21105840802192688,
#   0.4520410895347595,
#   -0.38845670223236084,
#   -0.14685845375061035,
#   -0.7852908968925476,
#   1.649366855621338,
#   1.4631212949752808,
#   1.412896990776062,
#   0.982630729675293,
#   -0.4829272925853729,
#   0.9236571788787842,
#   -0.7657669186592102,
#   -0.09452556073665619,
#   0.30165305733680725,
#   0.04887987673282623,
#   -0.3396701216697693,
#   -0.9837518334388733,
#   -0.16657404601573944,
#   3.1944010257720947,
#   0.7855151295661926,
#   0.04480277746915817,
#   0.10063733160495758,
#   -1.7784569263458252,
#   -1.1584358215332031,
#   0.6609106659889221,
#   -0.4596780836582184,
#   0.7787728905677795,
#   0.22876153886318207,
#   -0.6023473739624023,
#   -0.07146532833576202,
#   0.38541653752326965,
#   1.3485711812973022,
#   -0.15232762694358826,
#   0.00971305649727583,
# ...

# %%
embedding.embed_query("What is the second letter of Greek Alphabet")
# Out:
# [0.5805691480636597,
#  0.08599960803985596,
#  -3.2920095920562744,
#  -1.6602323055267334,
#  1.7477500438690186,
#  -0.9487202167510986,
#  -0.8373794555664062,
#  -0.019423415884375572,
#  -0.2795114517211914,
#  -0.32358819246292114,
#  -0.9602221250534058,
#  2.74772047996521,
#  1.2723950147628784,
#  0.16653798520565033,
#  0.8896005153656006,
#  -1.077929139137268,
#  0.615568220615387,
#  -0.860482931137085,
#  -1.1938278675079346,
#  5.114503073855303e-05,
#  -1.0995550155639648,
#  -0.5209180116653442,
#  -0.17136143147945404,
#  -0.5126332640647888,
#  2.0451998710632324,
#  1.7036311626434326,
#  1.9340142011642456,
#  0.6967935562133789,
#  -0.5949856638908386,
#  -1.0060546398162842,
#  -0.9951037764549255,
#  -0.2560326159000397,
#  0.8540593981742859,
#  -1.4595719575881958,
#  0.2604895532131195,
#  0.18355287611484528,
#  -0.42198699712753296,
#  0.9847483038902283,
#  0.08678195625543594,
#  -0.14275886118412018,
#  -0.29526805877685547,
#  -1.0710777044296265,
# ...
